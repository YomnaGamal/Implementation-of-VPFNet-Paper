# %%
# !nvidia-smi
# Out:
# Thu Jan  6 18:51:26 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   70C    P8    34W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# Simply comment Line 5, 13, 93-97 in demo.py. Save data_dict and pred_dict as pkl. Download it and visualize the result locally.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # PV-RCNN

# %% [markdown]
# ## Install PV-RCNN and its dependances

# %%
# %%capture
# !pip install spconv-cu102

# %%
# !git clone https://github.com/open-mmlab/OpenPCDet.git
# Out:
# Cloning into 'OpenPCDet'...
# remote: Enumerating objects: 2632, done.
# remote: Total 2632 (delta 0), reused 0 (delta 0), pack-reused 2632
# Receiving objects: 100% (2632/2632), 3.28 MiB | 4.49 MiB/s, done.
# Resolving deltas: 100% (1548/1548), done.
# Checking out files: 100% (206/206), done.

# %%
# %cd /content/drive/MyDrive/Masters/SDC/Project/OpenPCDet/
# Out:
# /content/drive/MyDrive/Masters/SDC/Project/OpenPCDet

# %%
# %%capture
# !pip install -r requirements.txt

# %% [markdown]
# ## Setup PV-RCNN

# %%
# !python setup.py develop

# %% [markdown]
# ## Demo

# %%
# %cd tools
# Out:
# /content/drive/MyDrive/Masters/SDC/Project/OpenPCDet/tools

# %%
# !python demo.py --cfg_file cfgs/kitti_models/pv_rcnn.yaml --ckpt ../../Models/pv_rcnn_8369.pth --data_path ../../000000.bin
# Out:
# 2022-01-06 19:00:56,730   INFO  -----------------Quick Demo of OpenPCDet-------------------------
# 2022-01-06 19:00:56,731   INFO  Total number of samples: 	1
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 2022-01-06 19:01:05,117   INFO  ==> Loading parameters from checkpoint ../../Models/pv_rcnn_8369.pth to CPU
# 2022-01-06 19:01:06,728   INFO  ==> Done (loaded 367/367)
# 2022-01-06 19:01:07,828   INFO  Visualized sample index: 	1
# 2022-01-06 19:01:11,762   INFO  Demo done.

# %% [markdown]
# # Ignore this section

# %% [markdown]
# @Yaccoub you are using K80 (sm_37) in colab which isn't supported by spconv prebuilts yet, will be added in spconv-cu102 2.1.21.
#
#
# https://github.com/open-mmlab/OpenPCDet/issues/273

# %%
# !unzip /content/drive/Shareddrives/GP_CSED_2021/data_lidar.zip -d "/content/data/"
# Out:
# Archive:  /content/drive/Shareddrives/GP_CSED_2021/data_lidar.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of /content/drive/Shareddrives/GP_CSED_2021/data_lidar.zip or
#         /content/drive/Shareddrives/GP_CSED_2021/data_lidar.zip.zip, and cannot find /content/drive/Shareddrives/GP_CSED_2021/data_lidar.zip.ZIP, period.

# %%
# %%capture
# !pip install open3d
# !pip install mayavi
